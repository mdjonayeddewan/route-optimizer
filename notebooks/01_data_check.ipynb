# %% [markdown]
# # Data Check
# Load and inspect raw location files for shape, nulls, and sample rows.

# %%
import pandas as pd

locations = pd.read_csv('../data/raw/locations.csv')
delivery = pd.read_csv('../data/raw/delivery_points.csv')

print('Locations shape:', locations.shape)
print('Delivery points shape:', delivery.shape)
display(locations.head())
display(delivery.head())
